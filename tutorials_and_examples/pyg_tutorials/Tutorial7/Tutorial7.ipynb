# %% [markdown]
# # Tutorial 7: ARGA & ARVGA
#
# Paper:
# * [Adversarially Regularized Graph Autoencoder for Graph Embedding](https://www.ijcai.org/Proceedings/2018/0362.pdf)
#
# Code:
#  * [ARGA & ARVGA](https://pytorch-geometric.readthedocs.io/en/latest/_modules/torch_geometric/nn/models/autoencoder.html)
#  * [Example on clustering](https://github.com/rusty1s/pytorch_geometric/blob/master/examples/argva_node_clustering.py)

# %%
import os

# Use the eager mode
os.environ['PT_HPU_LAZY_MODE'] = '0'

# Verify the environment variable is set
print(f"PT_HPU_LAZY_MODE: {os.environ['PT_HPU_LAZY_MODE']}")

import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

import habana_frameworks.torch.core as htcore
# Out:
# PT_HPU_LAZY_MODE: 0
# Calling add_step_closure function does not have any effect. It's lazy mode only functionality. (warning logged once)
# Calling mark_step function does not have any effect. It's lazy mode only functionality. (warning logged once)
# Calling iter_mark_step function does not have any effect. It's lazy mode only functionality. (warning logged once)
# 2.4.0a0+git74cd574
# /usr/lib/python3.10/inspect.py:288: FutureWarning: `torch.distributed.reduce_op` is deprecated, please use `torch.distributed.ReduceOp` instead
#   return isinstance(object, types.FunctionType)

# %% [markdown]
# ## Imports

# %%
import os.path as osp
import torch
import torch.nn.functional as F
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import (v_measure_score, homogeneity_score, completeness_score)
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import torch_geometric.transforms as T
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv
from torch_geometric.nn.models.autoencoder import ARGVA
from torch_geometric.utils import train_test_split_edges

# %% [markdown]
# ## Define the dataset

# %% [markdown]
# Download the dataset

# %%
dataset = 'Cora'
path = osp.join('.', 'data', dataset)
dataset = Planetoid(path, dataset, transform=T.NormalizeFeatures())
data = dataset.get(0)
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# Get the number of nodes

# %%
num_nodes = data.x.shape[0]

# %% [markdown]
# Create the train/val/test data

# %%
data.train_mask = data.val_mask = data.test_mask = None
data = train_test_split_edges(data)
data
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'train_test_split_edges' is deprecated, use 'transforms.RandomLinkSplit' instead
#   warnings.warn(out)
# Data(x=[2708, 1433], y=[2708], val_pos_edge_index=[2, 263], test_pos_edge_index=[2, 527], train_pos_edge_index=[2, 8976], train_neg_adj_mask=[2708, 2708], val_neg_edge_index=[2, 263], test_neg_edge_index=[2, 527])

# %% [markdown]
# ## Define the model

# %% [markdown]
# Define the encoder classes (the same as in `Tutorial 6`)

# %%
class VEncoder(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super(VEncoder, self).__init__()
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=True)
        self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=True)
        self.conv_logstd = GCNConv(2 * out_channels, out_channels, cached=True)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)

# %% [markdown]
# Define the discriminator class

# %%
class Discriminator(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(Discriminator, self).__init__()
        self.lin1 = torch.nn.Linear(in_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, hidden_channels)
        self.lin3 = torch.nn.Linear(hidden_channels, out_channels)

    def forward(self, x):
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = self.lin3(x)
        return x

# %% [markdown]
# Define the training algorithm

# %%
def train():
    model.train()
    encoder_optimizer.zero_grad()
    
    z = model.encode(data.x, data.train_pos_edge_index)

    for i in range(5):
        idx = range(num_nodes)  
        discriminator.train()
        discriminator_optimizer.zero_grad()
        discriminator_loss = model.discriminator_loss(z[idx]) # Comment
        discriminator_loss.backward(retain_graph=True)
        discriminator_optimizer.step()
 
    loss = 0
    loss = loss + model.reg_loss(z)  # Comment
    
    loss = loss + model.recon_loss(z, data.train_pos_edge_index)
    loss = loss + (1 / data.num_nodes) * model.kl_loss()
    loss.backward()

    encoder_optimizer.step()
    
    return loss

# %% [markdown]
# Define a training test method

# %%
@torch.no_grad()
def test():
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)

    # Cluster embedded values using k-means.
    kmeans_input = z.cpu().numpy()
    kmeans = KMeans(n_clusters=7, random_state=0).fit(kmeans_input)
    pred = kmeans.predict(kmeans_input)

    labels = data.y.cpu().numpy()
    completeness = completeness_score(labels, pred)
    hm = homogeneity_score(labels, pred)
    nmi = v_measure_score(labels, pred)

    auc, ap = model.test(z, data.test_pos_edge_index, data.test_neg_edge_index)

    return auc, ap, completeness, hm, nmi

# %% [markdown]
# ## Initialize the model

# %% [markdown]
# Initialize an encoder and a discriminator

# %%
latent_size = 32
encoder = VEncoder(data.num_features, out_channels=latent_size)

discriminator = Discriminator(in_channels=latent_size, hidden_channels=64, 
                              out_channels=1) # Comment

# %% [markdown]
# Initialize the model and move everything to the GPU

# %%
model = ARGVA(encoder, discriminator)

# device = torch.device('cuda' if torch.cuda.is_available() and use_cuda else 'cpu')
device = torch.device('hpu')
model, data = model.to(device), data.to(device)
# Out:
# ============================= HABANA PT BRIDGE CONFIGURATION ===========================
#  PT_HPU_LAZY_MODE = 0
#  PT_RECIPE_CACHE_PATH =
#  PT_CACHE_FOLDER_DELETE = 0
#  PT_HPU_RECIPE_CACHE_CONFIG =
#  PT_HPU_MAX_COMPOUND_OP_SIZE = 9223372036854775807
#  PT_HPU_LAZY_ACC_PAR_MODE = 1
#  PT_HPU_ENABLE_REFINE_DYNAMIC_SHAPES = 0
#  PT_HPU_EAGER_PIPELINE_ENABLE = 1
#  PT_HPU_EAGER_COLLECTIVE_PIPELINE_ENABLE = 1
# ---------------------------: System Configuration :---------------------------
# Num CPU Cores : 160
# CPU RAM       : 2113407800 KB
# ------------------------------------------------------------------------------

# %% [markdown]
# Define the optimizers

# %%
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.001)
encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=0.005)

# %% [markdown]
# ### Train the model

# %%
model.train()
model = torch.compile(model, backend="hpu_backend")
for epoch in range(1, 201):
    loss = train()
    auc, ap, completeness, hm, nmi = test()
    print((f'Epoch: {epoch:03d}, Loss: {loss:.3f}, AUC: {auc:.3f}, '
           f'AP: {ap:.3f}, Completeness: {completeness:.3f}, '
           f'Homogeneity: {hm:.3f}, NMI: {nmi:.3f}'))
# Out:
# Epoch: 001, Loss: 5.485, AUC: 0.718, AP: 0.725, Completeness: 0.062, Homogeneity: 0.061, NMI: 0.062
# Epoch: 002, Loss: 4.833, AUC: 0.700, AP: 0.717, Completeness: 0.073, Homogeneity: 0.073, NMI: 0.073
# Epoch: 003, Loss: 4.391, AUC: 0.691, AP: 0.713, Completeness: 0.069, Homogeneity: 0.067, NMI: 0.068
# Epoch: 004, Loss: 3.984, AUC: 0.691, AP: 0.715, Completeness: 0.073, Homogeneity: 0.069, NMI: 0.071
# Epoch: 005, Loss: 3.622, AUC: 0.698, AP: 0.721, Completeness: 0.095, Homogeneity: 0.092, NMI: 0.094
# Epoch: 006, Loss: 3.265, AUC: 0.710, AP: 0.731, Completeness: 0.132, Homogeneity: 0.133, NMI: 0.133
# Epoch: 007, Loss: 2.905, AUC: 0.724, AP: 0.744, Completeness: 0.158, Homogeneity: 0.159, NMI: 0.159
# Epoch: 008, Loss: 2.674, AUC: 0.727, AP: 0.747, Completeness: 0.164, Homogeneity: 0.162, NMI: 0.163
# Epoch: 009, Loss: 2.504, AUC: 0.717, AP: 0.737, Completeness: 0.157, Homogeneity: 0.160, NMI: 0.158
# Epoch: 010, Loss: 2.505, AUC: 0.708, AP: 0.729, Completeness: 0.160, Homogeneity: 0.156, NMI: 0.158
# Epoch: 011, Loss: 2.641, AUC: 0.704, AP: 0.725, Completeness: 0.179, Homogeneity: 0.175, NMI: 0.177
# Epoch: 012, Loss: 2.796, AUC: 0.708, AP: 0.727, Completeness: 0.181, Homogeneity: 0.175, NMI: 0.178
# Epoch: 013, Loss: 2.833, AUC: 0.717, AP: 0.733, Completeness: 0.209, Homogeneity: 0.206, NMI: 0.207
# Epoch: 014, Loss: 2.765, AUC: 0.728, AP: 0.741, Completeness: 0.223, Homogeneity: 0.223, NMI: 0.223
# Epoch: 015, Loss: 2.747, AUC: 0.736, AP: 0.746, Completeness: 0.217, Homogeneity: 0.212, NMI: 0.215
# Epoch: 016, Loss: 2.791, AUC: 0.738, AP: 0.748, Completeness: 0.227, Homogeneity: 0.226, NMI: 0.227
# Epoch: 017, Loss: 2.863, AUC: 0.734, AP: 0.746, Completeness: 0.210, Homogeneity: 0.206, NMI: 0.208
# Epoch: 018, Loss: 2.990, AUC: 0.728, AP: 0.742, Completeness: 0.231, Homogeneity: 0.230, NMI: 0.231
# Epoch: 019, Loss: 3.118, AUC: 0.725, AP: 0.740, Completeness: 0.222, Homogeneity: 0.218, NMI: 0.220
# Epoch: 020, Loss: 3.242, AUC: 0.725, AP: 0.741, Completeness: 0.232, Homogeneity: 0.234, NMI: 0.233
# Epoch: 113, Loss: 4.037, AUC: 0.836, AP: 0.815, Completeness: 0.395, Homogeneity: 0.373, NMI: 0.384
# Epoch: 114, Loss: 3.938, AUC: 0.834, AP: 0.813, Completeness: 0.408, Homogeneity: 0.384, NMI: 0.396
# Epoch: 115, Loss: 4.017, AUC: 0.834, AP: 0.812, Completeness: 0.404, Homogeneity: 0.384, NMI: 0.394
# Epoch: 116, Loss: 3.970, AUC: 0.835, AP: 0.813, Completeness: 0.403, Homogeneity: 0.384, NMI: 0.393
# Epoch: 117, Loss: 3.904, AUC: 0.836, AP: 0.816, Completeness: 0.400, Homogeneity: 0.384, NMI: 0.392
# Epoch: 118, Loss: 3.959, AUC: 0.839, AP: 0.821, Completeness: 0.386, Homogeneity: 0.378, NMI: 0.382
# Epoch: 119, Loss: 3.882, AUC: 0.842, AP: 0.825, Completeness: 0.390, Homogeneity: 0.383, NMI: 0.386
# Epoch: 120, Loss: 3.927, AUC: 0.846, AP: 0.829, Completeness: 0.386, Homogeneity: 0.369, NMI: 0.377
# Epoch: 121, Loss: 3.971, AUC: 0.849, AP: 0.832, Completeness: 0.386, Homogeneity: 0.368, NMI: 0.377
# Epoch: 122, Loss: 3.968, AUC: 0.853, AP: 0.835, Completeness: 0.388, Homogeneity: 0.378, NMI: 0.383
# Epoch: 123, Loss: 4.001, AUC: 0.855, AP: 0.838, Completeness: 0.375, Homogeneity: 0.357, NMI: 0.366
# Epoch: 124, Loss: 3.958, AUC: 0.858, AP: 0.840, Completeness: 0.372, Homogeneity: 0.365, NMI: 0.368
# Epoch: 125, Loss: 4.119, AUC: 0.859, AP: 0.841, Completeness: 0.365, Homogeneity: 0.358, NMI: 0.362
# Epoch: 126, Loss: 4.153, AUC: 0.860, AP: 0.841, Completeness: 0.351, Homogeneity: 0.333, NMI: 0.342
# Epoch: 127, Loss: 4.347, AUC: 0.859, AP: 0.841, Completeness: 0.349, Homogeneity: 0.323, NMI: 0.335
# Epoch: 128, Loss: 4.316, AUC: 0.858, AP: 0.841, Completeness: 0.381, Homogeneity: 0.362, NMI: 0.371
# Epoch: 129, Loss: 4.454, AUC: 0.857, AP: 0.841, Completeness: 0.342, Homogeneity: 0.312, NMI: 0.326
# Epoch: 130, Loss: 4.425, AUC: 0.856, AP: 0.842, Completeness: 0.339, Homogeneity: 0.315, NMI: 0.327
# Epoch: 131, Loss: 4.465, AUC: 0.857, AP: 0.843, Completeness: 0.344, Homogeneity: 0.316, NMI: 0.330
# Epoch: 132, Loss: 4.463, AUC: 0.858, AP: 0.844, Completeness: 0.350, Homogeneity: 0.324, NMI: 0.337
# Epoch: 133, Loss: 4.462, AUC: 0.860, AP: 0.845, Completeness: 0.349, Homogeneity: 0.324, NMI: 0.336
# Epoch: 134, Loss: 4.387, AUC: 0.861, AP: 0.846, Completeness: 0.349, Homogeneity: 0.326, NMI: 0.337
# Epoch: 135, Loss: 4.428, AUC: 0.861, AP: 0.847, Completeness: 0.355, Homogeneity: 0.335, NMI: 0.345
# Epoch: 159, Loss: 4.576, AUC: 0.865, AP: 0.856, Completeness: 0.411, Homogeneity: 0.379, NMI: 0.394
# Epoch: 160, Loss: 4.566, AUC: 0.865, AP: 0.856, Completeness: 0.405, Homogeneity: 0.366, NMI: 0.384
# Epoch: 161, Loss: 4.472, AUC: 0.865, AP: 0.856, Completeness: 0.375, Homogeneity: 0.369, NMI: 0.372
# Epoch: 162, Loss: 4.454, AUC: 0.865, AP: 0.855, Completeness: 0.373, Homogeneity: 0.372, NMI: 0.373
# Epoch: 163, Loss: 4.468, AUC: 0.866, AP: 0.855, Completeness: 0.379, Homogeneity: 0.374, NMI: 0.377
# Epoch: 164, Loss: 4.354, AUC: 0.867, AP: 0.855, Completeness: 0.380, Homogeneity: 0.374, NMI: 0.377
# Epoch: 165, Loss: 4.375, AUC: 0.867, AP: 0.855, Completeness: 0.381, Homogeneity: 0.376, NMI: 0.379
# Epoch: 166, Loss: 4.329, AUC: 0.867, AP: 0.855, Completeness: 0.375, Homogeneity: 0.372, NMI: 0.374
# Epoch: 167, Loss: 4.206, AUC: 0.867, AP: 0.856, Completeness: 0.385, Homogeneity: 0.380, NMI: 0.382
# Epoch: 168, Loss: 4.072, AUC: 0.868, AP: 0.856, Completeness: 0.385, Homogeneity: 0.380, NMI: 0.383
# Epoch: 169, Loss: 4.086, AUC: 0.868, AP: 0.856, Completeness: 0.377, Homogeneity: 0.368, NMI: 0.372
# Epoch: 170, Loss: 4.049, AUC: 0.869, AP: 0.857, Completeness: 0.415, Homogeneity: 0.374, NMI: 0.394
# Epoch: 171, Loss: 3.843, AUC: 0.869, AP: 0.858, Completeness: 0.381, Homogeneity: 0.380, NMI: 0.381
# Epoch: 172, Loss: 3.848, AUC: 0.869, AP: 0.858, Completeness: 0.390, Homogeneity: 0.385, NMI: 0.387
# Epoch: 173, Loss: 3.775, AUC: 0.870, AP: 0.859, Completeness: 0.403, Homogeneity: 0.366, NMI: 0.384
# Epoch: 174, Loss: 3.766, AUC: 0.871, AP: 0.861, Completeness: 0.371, Homogeneity: 0.373, NMI: 0.372
# Epoch: 175, Loss: 3.753, AUC: 0.872, AP: 0.861, Completeness: 0.409, Homogeneity: 0.382, NMI: 0.395
# Epoch: 176, Loss: 3.713, AUC: 0.872, AP: 0.862, Completeness: 0.406, Homogeneity: 0.381, NMI: 0.393
# Epoch: 177, Loss: 3.744, AUC: 0.871, AP: 0.861, Completeness: 0.399, Homogeneity: 0.378, NMI: 0.388
# Epoch: 178, Loss: 3.810, AUC: 0.871, AP: 0.861, Completeness: 0.372, Homogeneity: 0.377, NMI: 0.375
# Epoch: 179, Loss: 3.831, AUC: 0.872, AP: 0.862, Completeness: 0.374, Homogeneity: 0.379, NMI: 0.377
# Epoch: 180, Loss: 3.831, AUC: 0.872, AP: 0.862, Completeness: 0.387, Homogeneity: 0.381, NMI: 0.384
# Epoch: 181, Loss: 3.901, AUC: 0.873, AP: 0.863, Completeness: 0.387, Homogeneity: 0.361, NMI: 0.373
# Epoch: 182, Loss: 3.904, AUC: 0.875, AP: 0.865, Completeness: 0.384, Homogeneity: 0.358, NMI: 0.371
# Epoch: 183, Loss: 3.823, AUC: 0.876, AP: 0.866, Completeness: 0.392, Homogeneity: 0.364, NMI: 0.377
# Epoch: 184, Loss: 3.983, AUC: 0.877, AP: 0.868, Completeness: 0.384, Homogeneity: 0.368, NMI: 0.376
# Epoch: 185, Loss: 3.873, AUC: 0.877, AP: 0.869, Completeness: 0.349, Homogeneity: 0.357, NMI: 0.353
# Epoch: 186, Loss: 3.990, AUC: 0.878, AP: 0.870, Completeness: 0.392, Homogeneity: 0.385, NMI: 0.388
# Epoch: 187, Loss: 4.011, AUC: 0.880, AP: 0.872, Completeness: 0.352, Homogeneity: 0.348, NMI: 0.350
# Epoch: 188, Loss: 3.942, AUC: 0.880, AP: 0.872, Completeness: 0.376, Homogeneity: 0.365, NMI: 0.371
# Epoch: 189, Loss: 4.027, AUC: 0.880, AP: 0.873, Completeness: 0.374, Homogeneity: 0.364, NMI: 0.369
# Epoch: 190, Loss: 3.997, AUC: 0.880, AP: 0.873, Completeness: 0.376, Homogeneity: 0.366, NMI: 0.371
# Epoch: 191, Loss: 4.061, AUC: 0.879, AP: 0.872, Completeness: 0.398, Homogeneity: 0.395, NMI: 0.397
# Epoch: 192, Loss: 4.047, AUC: 0.877, AP: 0.871, Completeness: 0.366, Homogeneity: 0.337, NMI: 0.351
# Epoch: 193, Loss: 4.069, AUC: 0.875, AP: 0.869, Completeness: 0.374, Homogeneity: 0.375, NMI: 0.375
# Epoch: 194, Loss: 4.075, AUC: 0.874, AP: 0.868, Completeness: 0.362, Homogeneity: 0.346, NMI: 0.354
# Epoch: 195, Loss: 4.231, AUC: 0.874, AP: 0.868, Completeness: 0.369, Homogeneity: 0.343, NMI: 0.355
# Epoch: 196, Loss: 4.286, AUC: 0.873, AP: 0.868, Completeness: 0.366, Homogeneity: 0.366, NMI: 0.366
# Epoch: 197, Loss: 4.219, AUC: 0.873, AP: 0.868, Completeness: 0.368, Homogeneity: 0.363, NMI: 0.366
# Epoch: 198, Loss: 4.216, AUC: 0.873, AP: 0.868, Completeness: 0.348, Homogeneity: 0.337, NMI: 0.342
# Epoch: 199, Loss: 4.265, AUC: 0.873, AP: 0.870, Completeness: 0.385, Homogeneity: 0.385, NMI: 0.385
# Epoch: 200, Loss: 4.214, AUC: 0.874, AP: 0.872, Completeness: 0.374, Homogeneity: 0.375, NMI: 0.375

# %%
@torch.no_grad()
def plot_points(colors):
    model.eval()
    z = model.encode(data.x, data.train_pos_edge_index)
    z = TSNE(n_components=2).fit_transform(z.cpu().numpy())
    y = data.y.cpu().numpy()

    fig = plt.figure(1, figsize=(8, 8))
    fig.clf()
    for i in range(dataset.num_classes):
        plt.scatter(z[y == i, 0], z[y == i, 1], s=20, color=colors[i])
    plt.axis('off')
    plt.show()

# %%
#%%
colors = [
    '#ffc0cb', '#bada55', '#008080', '#420420', '#7fe5f0', '#065535', '#ffd700'
]
plot_points(colors)
